# %%
import cv2
import numpy
import glob
import pylab as plt
import os
import matplotlib.pyplot as plt
from skimage.io import imread, imshow
from skimage import data
# Out:
# C:\Users\kiran kumar\Anaconda3\lib\site-packages\dask\config.py:168: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
#   data = yaml.load(f.read()) or {}

# %%
import os
os.chdir(r'C:\Users\kiran kumar\Documents\Python\Image_processing\Others')

# %%
ls
# Out:
#  Volume in drive C is OS
#  Volume Serial Number is 86F0-F3DB
#
#  Directory of C:\Users\kiran kumar\Documents\Python\Image_processing\Others
#
# 03/02/2020  03:31 PM    <DIR>          .
# 03/02/2020  03:31 PM    <DIR>          ..
# 02/26/2020  08:58 PM            11,223 Others1.jpg
# 02/26/2020  04:36 PM             9,899 Others10.jpg
# 02/26/2020  04:35 PM           244,743 Others100.jpg
# 02/26/2020  04:35 PM           364,412 Others1000.jpg
# 02/26/2020  04:36 PM            13,078 Others1001.jpg
# 02/26/2020  04:36 PM            14,915 Others1002.jpg
# 02/26/2020  04:36 PM            10,038 Others1003.jpg
# 02/26/2020  04:35 PM           239,683 Others1004.jpg
# 02/26/2020  04:36 PM            13,484 Others1005.jpg
# 02/26/2020  04:36 PM             8,804 Others1006.jpg
# 02/26/2020  08:57 PM            13,454 Others1007.jpg
# 02/26/2020  04:35 PM           354,043 Others1008.jpg
# 02/26/2020  08:57 PM            10,041 Others1009.jpg
# ...

# %% [markdown]
# ## Others

# %%
plt.figure(figsize=(10,5))
plt.subplot(121)
image = imread('Others1.jpg')
plt.imshow(image)

plt.subplot(122)
image_gray = imread('Others1.jpg',as_gray=True)
plt.imshow(image_gray)

# %%
plt.figure(figsize=(10,5))
plt.subplot(121)
plt.hist(image.ravel())

plt.subplot(122)
plt.hist(image_gray.ravel())
# Out:
# (array([  236.,  7457., 31227.,  9978., 24807., 42013., 68685., 84091.,
#         21366., 19412.]),
#  array([0.04750431, 0.14241459, 0.23732486, 0.33223514, 0.42714541,
#         0.52205569, 0.61696596, 0.71187624, 0.80678651, 0.90169678,
#         0.99660706]),
#  <a list of 10 Patch objects>)

# %%
plt.figure(figsize=(10,5))
color = ('b','g','r')
for i,col in enumerate(color):
    histr = cv2.calcHist([image],[i],None,[256],[0,256])
    plt.plot(histr,color = col)
    plt.xlim([0,256])
    
plt.show()

# %% [markdown]
# ## 10_Rupees

# %%
os.chdir(r'C:\Users\kiran kumar\Documents\Python\Image_processing\10_Rupees')

# %%
ls
# Out:
#  Volume in drive C is OS
#  Volume Serial Number is 86F0-F3DB
#
#  Directory of C:\Users\kiran kumar\Documents\Python\Image_processing\10_Rupees
#
# 03/02/2020  03:46 PM    <DIR>          .
# 03/02/2020  03:46 PM    <DIR>          ..
# 02/27/2020  10:09 PM            85,879 10_Rupees1.jpg
# 02/27/2020  10:10 PM            19,057 10_Rupees10.jpg
# 02/27/2020  10:10 PM           140,892 10_Rupees100.jpg
# 02/27/2020  10:09 PM            51,106 10_Rupees1000.jpg
# 02/27/2020  10:10 PM             3,361 10_Rupees1001.jpg
# 02/27/2020  10:10 PM             9,563 10_Rupees1002.jpg
# 02/27/2020  10:10 PM             4,091 10_Rupees1003.jpg
# 02/27/2020  10:10 PM             3,943 10_Rupees1004.jpg
# 02/27/2020  10:09 PM             2,904 10_Rupees1005.jpg
# 02/27/2020  10:10 PM            75,533 10_Rupees1006.jpg
# 02/27/2020  10:10 PM             3,948 10_Rupees1007.jpg
# 02/27/2020  10:10 PM             4,370 10_Rupees1008.jpg
# 02/27/2020  10:10 PM             5,189 10_Rupees1009.jpg
# ...

# %%
plt.figure(figsize=(10,5))
plt.subplot(121)
image_10 = imread('10_Rupees1.jpg')
plt.imshow(image_10)

plt.subplot(122)
image_gray_10 = imread('10_Rupees1.jpg',as_gray=True)
plt.imshow(image_gray_10)

# %%
plt.figure(figsize=(10,5))
plt.subplot(121)
plt.hist(image_10.ravel())

plt.subplot(122)
plt.hist(image_gray_10.ravel())
# Out:
# (array([  236.,  7457., 31227.,  9978., 24807., 42013., 68685., 84091.,
#         21366., 19412.]),
#  array([0.04750431, 0.14241459, 0.23732486, 0.33223514, 0.42714541,
#         0.52205569, 0.61696596, 0.71187624, 0.80678651, 0.90169678,
#         0.99660706]),
#  <a list of 10 Patch objects>)

# %%
plt.figure(figsize=(10


# %%
plt.figure(figsize=(10,5))
plt.subplot(121)
plt.hist(image_50.ravel())

plt.subplot(122)
plt.hist(image_gray_50.ravel())
# Out:
# (array([ 26974.,  66701., 108107.,  93984., 110710.,  98575.,  91761.,
#          98387.,  58299.,  32934.]),
#  array([0.08262157, 0.17064031, 0.25865906, 0.3466778 , 0.43469655,
#         0.52271529, 0.61073404, 0.69875278, 0.78677153, 0.87479027,
#         0.96280902]),
#  <a list of 10 Patch objects>)

# %%
plt.figure(figsize=(10,5))
color = ('b','g','r')
for i,col in enumerate(color):
    histr = cv2.calcHist([image_50],[i],None,[256],[0,256])
    plt.plot(histr,color = col)
    plt.xlim([0,256])
    
plt.show()

# %% [markdown]
# ## 100_Rupees

# %%
os.chdir(r'C:\Users\kiran kumar\Documents\Python\Image_processing\100_Rupees')

# %%
ls
# Out:
#  Volume in drive C is OS
#  Volume Serial Number is 86F0-F3DB
#
#  Directory of C:\Users\kiran kumar\Documents\Python\Image_processing\100_Rupees
#
# 03/02/2020  03:34 PM    <DIR>          .
# 03/02/2020  03:34 PM    <DIR>          ..
# 02/28/2020  03:55 PM            61,532 100_Rupees1.jpg
# 02/28/2020  03:56 PM            17,792 100_Rupees10.jpg
# 02/28/2020  03:55 PM            78,187 100_Rupees100.jpg
# 02/28/2020  03:55 PM           108,473 100_Rupees1000.jpg
# 02/28/2020  03:56 PM            20,922 100_Rupees1001.jpg
# 02/28/2020  03:56 PM            17,867 100_Rupees1002.jpg
# 02/28/2020  03:56 PM            19,503 100_Rupees1003.jpg
# 02/28/2020  03:55 PM           109,871 100_Rupees1004.jpg
# 02/28/2020  03:56 PM            20,919 100_Rupees1005.jpg
# 02/28/2020  03:56 PM            22,282 100_Rupees1006.jpg
# 02/28/2020  03:56 PM            20,371 100_Rupees1007.jpg
# 02/28/2020  03:56 PM            22,366 100_Rupees1008.jpg
# ...

# %%
plt.subplot(121)
image_100 = imread('100_Rupees1.jpg')
plt.imshow(image_100)

plt.subplot(122)
image_gray_100 = imread('100_Rupees1.jpg',as_gray=True)
plt.imshow(image_gray_100)

# %%
plt.figure(figsize=(10,5))
plt.subplot(121)
plt.hist(image_100.ravel())

plt.subplot(122)
plt.hist(image_gray_100.ravel())
# Out:
# (array([  366.,  4522., 21938., 12708., 13369., 19239., 52325., 57698.,
#         12386.,  1073.]),
#  array([0.10138039, 0.1911858 , 0.28099122, 0.37079663, 0.46060204,
#         0.55040745, 0.64021286, 0.73001827, 0.81982369, 0.9096291 ,
#         0.99943451]),
#  <a list of 10 Patch objects>)

# %%
plt.figure(figsize=(10,5))
color = ('b','g','r')
for i,col in enumerate(color):
    histr = cv2.calcHist([image_100],[i],None,[256],[0,256])
    plt.plot(histr,color = col)
    plt.xlim([0,256])
    
plt.show()

# %% [markdown]
# ### 500_Rupees

# %%
os.chdir(r'C:\Users\kiran kumar\Documents\Python\Image_processing\500_Rupees')

# %%
ls
# Out:
#  Volume in drive C is OS
#  Volume Serial Number is 86F0-F3DB
#
#  Directory of C:\Users\kiran kumar\Documents\Python\Image_processing\500_Rupees
#
# 03/02/2020  03:34 PM    <DIR>          .
# 03/02/2020  03:34 PM    <DIR>          ..
# 02/27/2020  08:38 PM           189,652 500_Rupees1.jpg
# 02/27/2020  08:37 PM           195,129 500_Rupees10.jpg
# 02/27/2020  08:37 PM           680,377 500_Rupees100.jpg
# 02/27/2020  08:37 PM           117,289 500_Rupees1000.jpg
# 02/27/2020  08:37 PM            25,485 500_Rupees101.jpg
# 02/27/2020  08:37 PM            81,780 500_Rupees102.jpg
# 02/27/2020  08:37 PM            97,210 500_Rupees103.jpg
# 02/27/2020  08:37 PM           681,529 500_Rupees104.jpg
# 02/27/2020  08:38 PM            25,485 500_Rupees105.jpg
# 02/27/2020  08:37 PM           105,251 500_Rupees106.jpg
# 02/27/2020  08:38 PM           113,450 500_Rupees107.jpg
# 02/27/2020  08:38 PM           702,905 500_Rupees108.jpg
# ...

# %%
plt.subplot(121)
image_500 = imread('500_Rupees1.jpg')
plt.imshow(image_500)

plt.subplot(122)
image_gray_500 = imread('500_Rupees1.jpg',as_gray=True)
plt.imshow(image_gray_500)

# %%
plt.figure(figsize=(10,5))
plt.subplot(121)
plt.hist(image_500.ravel())

plt.subplot(122)
plt.hist(image_gray_500.ravel())
# Out:
# (array([  2043.,  21345., 147169.,  71573.,  98914., 106092., 125635.,
#         143626., 404512., 119291.]),
#  array([0.00333333, 0.103     , 0.20266667, 0.30233333, 0.402     ,
#         0.50166667, 0.60133333, 0.701     , 0.80066667, 0.90033333,
#         1.        ]),
#  <a list of 10 Patch objects>)

# %%
plt.figure(figsize=(10,5))
color = ('b','g','r')
for i,col in enumerate(color):
    histr = cv2.calcHist([image_500],[i],None,[256],[0,256])
    plt.plot(histr,color = col)
    plt.xlim([0,256])
    
plt.show()

# %% [markdown]
# ## 2000_Rupess

# %%
os.chdir(r'C:\Users\kiran kumar\Documents\Python\Image_processing\2000_Rupees')

# %%
ls
# Out:
#  Volume in drive C is OS
#  Volume Serial Number is 86F0-F3DB
#
#  Directory of C:\Users\kiran kumar\Documents\Python\Image_processing\2000_Rupees
#
# 03/02/2020  03:33 PM    <DIR>          .
# 03/02/2020  03:33 PM    <DIR>          ..
# 02/28/2020  12:29 PM           249,495 2000_Rupees1.jpg
# 02/28/2020  12:33 PM             3,711 2000_Rupees10.jpg
# 02/28/2020  12:33 PM             2,518 2000_Rupees100.jpg
# 02/28/2020  12:32 PM           229,506 2000_Rupees1000.jpg
# 02/28/2020  12:32 PM            23,011 2000_Rupees1001.jpg
# 02/28/2020  12:32 PM             1,584 2000_Rupees1002.jpg
# 02/28/2020  12:32 PM           208,869 2000_Rupees1003.jpg
# 02/28/2020  12:32 PM           231,099 2000_Rupees1004.jpg
# 02/28/2020  12:32 PM           180,225 2000_Rupees1005.jpg
# 02/28/2020  12:29 PM           269,255 2000_Rupees1006.jpg
# 02/28/2020  12:29 PM            14,125 2000_Rupees1007.jpg
# 02/28/2020  12:32 PM           196,485 2000_Rupees1008.jpg
# ...

# %%
plt.subplot(121)
image_2000 = imread('2000_Rupees1.jpg')
plt.imshow(image_2000)

plt.subplot(122)
image_gray_2000 = imread('2000_Rupees1.jpg',as_gray=True)
plt.imshow(image_gray_2000)

# %%
plt.figure(figsize=(10,5))
plt.subplot(121)
plt.hist(image_2000.ravel())

plt.subplot(122)
plt.hist(image_gray_2000.ravel())
# Out:
# (array([  21299.,    5578.,   33465.,   60318.,   98283.,  189635.,
#          370136.,  908789., 1188264.,  369033.]),
#  array([0.01232235, 0.08672353, 0.16112471, 0.23552588, 0.30992706,
#         0.38432824, 0.45872941, 0.53313059, 0.60753176, 0.68193294,
#         0.75633412]),
#  <a list of 10 Patch objects>)

# %%
plt.figure(figsize=(10,5))
color = ('b','g','r')
for i,col in enumerate(color):
    histr = cv2.calcHist([image_2000],[i],None,[256],[0,256])
    plt.plot(histr,color = col)
    plt.xlim([0,256])
    
plt.show()

# %%
from skimage.filters import prewitt_h,prewitt_v

# %%
#importing the required libraries
import numpy as np
from skimage.io import imread, imshow
from skimage.filters import prewitt_h,prewitt_v
import matplotlib.pyplot as plt
# %matplotlib inline

#reading the image 
image = imread('2000_Rupees1.jpg',as_gray=True)

#calculating horizontal edges using prewitt kernel
edges_prewitt_horizontal = prewitt_h(image)
#calculating vertical edges using prewitt kernel
edges_prewitt_vertical = prewitt_v(image)

imshow(edges_prewitt_vertical, cmap='gray')

# %%
img = cv2.imread('2000_Rupees1.jpg',0)
edges = cv2.Canny(img,100,200)
plt.subplot(121),plt.imshow(img,cmap = 'gray')
plt.title('Original Image'), plt.xticks([]), plt.yticks([])
plt.subplot(122),plt.imshow(edges,cmap = 'gray')
plt.title('Edge Image'), plt.xticks([]), plt.yticks([])
plt.show()
